# %%
import numpy as np
import pandas as pd
import openpyxl

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 매뉴얼
#
# 1. 시작전 틀이 갖춰진 비어있는 엑셀 파일이 필요함.
# 2. 해당 URL을 검수 Raw 파일의 URL에 넣는다.
#
# 따옴표 같은건 못잡아냄
# twitter 이미지, twitter 카드, Schema(Breadcrumb) 은 글자가 있으면 O로 해놨음

# %% [markdown]
# ## 검수 국가 설정

# %%
countrys = ["AW"]

# %% [markdown]
# ## 경로설정

# %%
raw_address = "F:/OneDrive/12. 라이브 이후 검수/Raw"
href_raw_address = "F:/OneDrive/12. 라이브 이후 검수/Raw/Herflang RAW"
save_address = "F:/OneDrive/12. 라이브 이후 검수"

# %% [markdown]
# ## 전처리(Raw 데이터 정리)

# %%
count_num = 0

for country in countrys:
    # 불러오기 1차(Raw, check Raw, ckeck)
    after_raw = pd.read_excel(raw_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+
                              country+")_Raw.xlsx")
    
    after_check = pd.read_excel(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("
                                +country+").xlsx", sheet_name ="검수")
    
    # 불러오기 2차
    after_check_raw_wb = openpyxl.load_workbook(save_address+"/"+
                                                "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    after_check_raw_ws = after_check_raw_wb['검수 Raw']
    
    # 전처리
    for i in range(after_check.shape[0]):
        if i < after_raw.shape[0]:
            url_index = after_raw[after_check['URL'][i] == after_raw['Address']].index[0]
            
            # 1.URL
            after_check_raw_ws['B'+str(i+2)] = after_raw['Address'][url_index]

            # 2.URL 구조
            after_check_raw_ws['C'+str(i+2)] = after_raw['Address'][url_index]

            # 3.캐노니컬
            after_check_raw_ws['D'+str(i+2)] = after_raw['Canonical Link Element 1'][url_index]

            # 4.타이틀
            after_check_raw_ws['E'+str(i+2)] = after_raw['Title 1'][url_index]

            # 5.디스크립션
            after_check_raw_ws['F'+str(i+2)] = after_raw['Meta Description 1'][url_index]
            
            # 6.OG
            after_check_raw_ws['G'+str(i+2)] = after_raw['OG : Site Name 1'][url_index]
            after_check_raw_ws['H'+str(i+2)] = after_raw['OG : Type 1'][url_index]
            after_check_raw_ws['I'+str(i+2)] = after_raw['OG : Title 1'][url_index] 
            after_check_raw_ws['J'+str(i+2)] = after_raw['OG : Description 1'][url_index] 
            after_check_raw_ws['K'+str(i+2)] = after_raw['OG : URL 1'][url_index]

            # 7.Twitter
            after_check_raw_ws['L'+str(i+2)] = after_raw['Twitter : Site 1'][url_index]
            after_check_raw_ws['M'+str(i+2)] = after_raw['Twitter : Title 1'][url_index]
            after_check_raw_ws['N'+str(i+2)] = after_raw['Twitter : Description 1'][url_index]
            after_check_raw_ws['O'+str(i+2)] = after_raw['Twitter : URL 1'][url_index]
            after_check_raw_ws['P'+str(i+2)] = after_raw['Twitter : Image 1'][url_index]
            after_check_raw_ws['Q'+str(i+2)] = after_raw['Twitter : Cards 1'][url_index]

            # 8.Schema
            after_check_raw_ws['R'+str(i+2)] = after_raw['Schema : Name 1'][url_index]
            after_check_raw_ws['S'+str(i+2)] = after_raw['Schema : Description 1'][url_index]
            after_check_raw_ws['T'+str(i+2)] = after_raw['Schema : URL 1'][url_index]
            after_check_raw_ws['U'+str(i+2)] = after_raw['BreadcrumbList 1'][url_index]
            after_check_raw_ws['V'+str(i+2)] = after_raw['Schema : Type Json 1'][url_index]

            # 9.H tag
            after_check_raw_ws['W'+str(i+2)] = after_raw['H1-1'][url_index]
            after_check_raw_ws['X'+str(i+2)] = after_raw['H2-1'][url_index]
            after_check_raw_ws['Y'+str(i+2)] = after_raw['H2-2'][url_index]
            
        else :
            break
            
    # 저장
    after_check_raw_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")

    # 결과
    count_num += 1
    print(count_num,". {} 의, 검수 Raw 파일 생성이 완료되었습니다.".format(country))
# Out:
# 20 . AW 의, 검수 Raw 파일 생성이 완료되었습니다.

# %% [markdown]
# ## 1. URL 구조(미완료)

# %%
any()


count_num = 0

for country in countrys:
    
    # 불러오기 1차
    url_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    
    # 불러오기 2차
    url_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    url_after_check_ws = url_after_check_wb['검수']

    # 검수
    s_char=['~','`','@','\']
    if any(char in invalidChars for char in word):
        print "Invalid"
    else:
        print "Valid"
    
    
    
    for i in range(url_after_check_raw.shape[0]):
        url_equal = url_after_check_raw['URL'][i] == url_after_check_raw['캐노니컬'][i]
        if url_equal == True: 
            url_after_check_ws['D'+str(i+2)] = "O"
        else:
            url_after_check_ws['D'+str(i+2)] = "X"
            
    # 저장
    url_after_check_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    
    # 결과
    count_num += 1
    print(count_num,". {} 의, 캐노니컬 항목 검수가 완료되었습니다.".format(country))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-201bcd98f374> in <module>
#       9     url_after_check_wb = openpyxl.load_workbook(save_address+"/"+
#      10                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
# ---> 11     url_after_check_ws = url_after_chack_wb['검수']
#      12
#      13     # 검수
#
# NameError: name 'url_after_chack_wb' is not defined

# %%
after_check_raw['URL'][0].
# Out:
# 'https://www.kia.com/aw/discover-kia/ask/how-is-the-kia-seltos-interior-design.html'

# %% [markdown]
# ## 2. 캐노니컬

# %%
count_num = 0

for country in countrys:
    
    # 불러오기 1차
    cano_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    
    # 불러오기 2차
    cano_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    cano_after_check_ws = cano_after_check_wb['검수']

    # 검수
    for i in range(cano_after_check_raw.shape[0]):
        cano_equal = cano_after_check_raw['URL'][i] == cano_after_check_raw['캐노니컬'][i]
        if cano_equal == True: 
            cano_after_check_ws['D'+str(i+2)] = "O"
        else:
            cano_after_check_ws['D'+str(i+2)] = "X"
            
    # 저장
    cano_after_check_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    
    # 결과
    count_num += 1
    print(count_num,". {} 의, 캐노니컬 항목 검수가 완료되었습니다.".format(country))
# Out:
# 1 . AW 의, 캐노니컬 항목 검수가 완료되었습니다.

# %% [markdown]
# ## 3. 타이틀

# %%
count_num = 0

for country in countrys:
    
    # 불러오기 1차
    title_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    
    # 불러오기 2차
    title_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    title_after_check_ws = title_after_check_wb['검수']

    # 검수
    for i in range(title_after_check_raw.shape[0]):
        title_equal = title_after_check_raw['URL'][i]
        title_equal_1 = title_equal.replace("https://www.kia.com/"+country.lower()+"/discover-kia/ask/","")
        title_equal_2 = title_equal_1.replace(".html","")
        title_equal_3 = title_equal_2.replace("-"," ").lower()
        if title_equal_3 in title_after_check_raw['타이틀'][i].lower(): 
            title_after_check_ws['E'+str(i+2)] = "O"
        else:
            title_after_check_ws['E'+str(i+2)] = "X"
            
    # 저장
    title_after_check_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    
    # 결과
    count_num += 1
    print(count_num,". {} 의, 타이틀 항목 검수가 완료되었습니다.".format(country))
# Out:
# 1 . AW 의, 타이틀 항목 검수가 완료되었습니다.

# %% [markdown]
# ## 4. 디스크립션 - 직접 타이틀과 비교해서 진행해야 함

# %% [markdown]
# ## 5. OG(site name, Type, Title, Description, URL)

# %%
count_num = 0

for country in countrys:
    
    # 불러오기 1차
    og_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    
    # 불러오기 2차
    og_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    og_after_check_ws = og_after_check_wb['검수']

    # Site name 검수
    for i in range(og_after_check_raw.shape[0]):
        if og_after_check_raw['OG(Site name)'][i].lower() in og_after_check_raw['타이틀'][i].lower():
            og_after_check_ws['G'+str(i+2)] = "O"
        else:
            og_after_check_ws['G'+str(i+2)] = "X"
            
    # Type 검수
    for i in range(og_after_check_raw.shape[0]):
        if og_after_check_raw['OG(Type)'][i] == 'website':
            og_after_check_ws['H'+str(i+2)] = "O"
        else:
            og_after_check_ws['H'+str(i+2)] = "X"
    
    # Title 검수
    for i in range(og_after_check_raw.shape[0]):
        if og_after_check_raw['OG(Title)'][i] == og_after_check_raw['타이틀'][i]:
            og_after_check_ws['I'+str(i+2)] = "O"
        else:
            og_after_check_ws['I'+str(i+2)] = "X"
    
    # Description 검수
    for i in range(og_after_check_raw.shape[0]):
        if og_after_check_raw['OG(Description)'][i] == og_after_check_raw['디스크립션'][i]:
            og_after_check_ws['J'+str(i+2)] = "O"
        else:
            og_after_check_ws['J'+str(i+2)] = "X"
    
    # URL 검수
    for i in range(og_after_check_raw.shape[0]):
        if og_after_check_raw['OG(URL)'][i] == og_after_check_raw['URL'][i]:
            og_after_check_ws['K'+str(i+2)] = "O"
        else:
            og_after_check_ws['K'+str(i+2)] = "X"
    
    # 저장
    og_after_check_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    
    # 결과
    count_num += 1
    print(count_num,". {} 의, OG 항목 검수가 완료되었습니다.".format(country))
# Out:
# 1 . AW 의, OG 항목 검수가 완료되었습니다.

# %% [markdown]
# ## 6. Twitter(Site, Title, Description, URL, Image, Twitter Card)

# %%
count_num = 0

for country in countrys:
    
    # 불러오기 1차
    twitter_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    
    # 불러오기 2차
    twitter_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    twitter_after_check_ws = twitter_after_check_wb['검수']

    # Site 검수
    for i in range(twitter_after_check_raw.shape[0]):
        if twitter_after_check_raw['Twitter(Site)'][i] in twitter_after_check_raw['타이틀'][i]:
            twitter_after_check_ws['L'+str(i+2)] = "O"
        else:
            twitter_after_check_ws['L'+str(i+2)] = "X"
            
    # Title 검수
    for i in range(twitter_after_check_raw.shape[0]):
        if twitter_after_check_raw['Twitter(Title)'][i] == twitter_after_check_raw['타이틀'][i]:
            twitter_after_check_ws['M'+str(i+2)] = "O"
        else:
            twitter_after_check_ws['M'+str(i+2)] = "X"
    
    # Description 검수
    for i in range(twitter_after_check_raw.shape[0]):
        if twitter_after_check_raw['Twitter(Description)'][i] == twitter_after_check_raw['디스크립션'][i]:
            twitter_after_check_ws['N'+str(i+2)] = "O"
        else:
            twitter_after_check_ws['N'+str(i+2)] = "X"
            
    # URL 검수
    for i in range(twitter_after_check_raw.shape[0]):
        if twitter_after_check_raw['Twitter(URL)'][i] == twitter_after_check_raw['URL'][i]:
            twitter_after_check_ws['O'+str(i+2)] = "O"
        else:
            twitter_after_check_ws['O'+str(i+2)] = "X"
            
    # Image 검수
    for i in range(twitter_after_check_raw.shape[0]):
        if twitter_after_check_raw['Twitter(Image)'][i] != '':
            twitter_after_check_ws['P'+str(i+2)] = "O"
        else:
            twitter_after_check_ws['P'+str(i+2)] = "X"
            
    # Twitter Card
    for i in range(twitter_after_check_raw.shape[0]):
        if twitter_after_check_raw['Twitter(Twitter Card)'][i] != '':
            twitter_after_check_ws['Q'+str(i+2)] = "O"
        else:
            twitter_after_check_ws['Q'+str(i+2)] = "X"
    
    # 저장
    twitter_after_check_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    
    # 결과
    count_num += 1
    print(count_num,". {} 의, twitter 항목 검수가 완료되었습니다.".format(country))
# Out:
# 1 . AW 의, twitter 항목 검수가 완료되었습니다.

# %% [markdown]
# ## 7. Schema(Name, Description, URL, Breadcrumb, type)

# %%
count_num = 0

for country in countrys:
    
    # 불러오기 1차
    schema_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    
    # 불러오기 2차
    schema_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    schema_after_check_ws = schema_after_check_wb['검수']

    # Name 검수
    for i in range(schema_after_check_raw.shape[0]):
        if schema_after_check_raw['Schema(Name)'][i] == schema_after_check_raw['타이틀'][i]:
            schema_after_check_ws['R'+str(i+2)] = "O"
        else:
            schema_after_check_ws['R'+str(i+2)] = "X"

    # Description 검수
    for i in range(schema_after_check_raw.shape[0]):
        if schema_after_check_raw['Schema(Description)'][i] == schema_after_check_raw['디스크립션'][i]:
            schema_after_check_ws['S'+str(i+2)] = "O"
        else:
            schema_after_check_ws['S'+str(i+2)] = "X"
            
    # URL 검수
    for i in range(schema_after_check_raw.shape[0]):
        if schema_after_check_raw['Schema(URL)'][i] == schema_after_check_raw['URL'][i]:
            schema_after_check_ws['T'+str(i+2)] = "O"
        else:
            schema_after_check_ws['T'+str(i+2)] = "X"
    
    # Breadcrumb 검수
    for i in range(schema_after_check_raw.shape[0]):
        if schema_after_check_raw['Schema(Breadcrumb)'][i] != '':
            schema_after_check_ws['U'+str(i+2)] = "O"
        else:
            schema_after_check_ws['U'+str(i+2)] = "X"
    
    # type 검수
    for i in range(schema_after_check_raw.shape[0]):
        if schema_after_check_raw['Schema(type)'][i] == 'WebPage':
            schema_after_check_ws['V'+str(i+2)] = "O"
        else:
            schema_after_check_ws['V'+str(i+2)] = "X"
    
    # 저장
    schema_after_check_wb.save(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    
    # 결과
    count_num += 1
    print(count_num,". {} 의, schema 항목 검수가 완료되었습니다.".format(country))
# Out:
# 1 . AW 의, schema 항목 검수가 완료되었습니다.

# %% [markdown]
# ## 8. H tag(H1, H2_1, H2_2) - 직접 싸이트에 들어가서 확인

# %%
count_num = 0

for country in countrys:
    
    # 불러오기 1차
    herf_after_check_raw = pd.read_excel(save_address+"/"+
                                        "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx",
                                        sheet_name ="검수 Raw")
    herf
    
    # 불러오기 2차
    herf_after_check_wb = openpyxl.load_workbook(save_address+"/"+
                                                 "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
    herf_after_check_ws = schema_after_check_wb['검수']

# %% [markdown]
# ## 9. Hreflang(preprocessing)

# %%
count_num = 0

for country in countrys:
    # 불러오기 1차
    href_after_raw_wb = openpyxl.load_workbook(href_raw_address+"/"+country+" hreflang_all_raw.xlsx")
    href_after_raw_ws = href_after_raw_wb["1 - All"]
    
    
    # 수정
    href_after_raw_ws.
    

    # 저장 1차
    href_after_raw_wb.save(href_raw_address+"/"+country+" hreflang_all_raw_check.xlsx")

    # 불러오기 2차(href Raw, hreflang 검수)
    href_after_raw = pd.read_excel(href_raw_address+"/"+country+" hreflang_all_raw.xlsx", sheet_name = "1 - All")
#     href_after_raw = pd.read_excel(href_raw_address+"/"+country+" hreflang_all_raw.xlsx",
#                                    sheet_name = "hreflang 검수")

    # null 행 제거
    not_null_index = href_after_raw['Sitemap hreflang 1 URL'].dropna().index
    not_null_raw= href_after_raw.iloc[not_null_index]
    
    # HTML hreflang 1 URL 검수
    not_null_raw['HTML hreflang 1 check'] = not_null_raw['HTML hreflang 1 URL'] == \
    'https://www.kia.com/worldwide/main.do'
    
    # HTML hreflang 2 URL 검수
    not_null_raw['HTML hreflang 2 check'] = not_null_raw['HTML hreflang 2 URL'] == \
    'https://www.kia.com/'+country.lower()+'/main.html'
    
    # Sitemap hreflang URL 검수
    for i in range(1,32):
        as_href = not_null_raw['Sitemap hreflang '+str(i+1)].str.split('-', n=1, expand=True).iloc[0,1]
        for j in range(not_null_raw.shape[0])
        address_url_equal = not_null_raw['Address'][i].replace("https://www.kia.com/"+
                                                            country.lower()+"/discover-kia/ask/", "")
        address_url_equal_1 = href_url_equal.replace(".html","")
        
        
        not_null_raw['Sitemap hreflang '+j+'URL check'] = address_url_equal_1 == 
        
        
        
        
    # 저장
    href_after_raw.to_excel(href_raw_address+"/"+country+" hreflang_all_raw_check.xlsx",
                                  sheet_name='hreflang 검수')
    
    
    
    
    # 

        title_equal = title_after_check_raw['URL'][i]
        title_equal_1 = title_equal.replace("https://www.kia.com/aw/discover-kia/ask/","")
        title_equal_2 = title_equal_1.replace(".html","")
        title_equal_3 = title_equal_2.replace("-"," ").lower()
    
    
    
    
    
        # columns drop 하기(맨 마지막에 하기)
#     drop_col = ['Title 1', 'Occurrences']
#     not_null_raw.drop(drop_col, axis=1, inplace=True)
    
    
    
#     # 불러오기 2차
    
#     href_after_check_wb = openpyxl.load_workbook(save_address+"/"+
#                                                  "2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+country+").xlsx")
#     href_after_check_ws = schema_after_check_wb['검수']
    
#     href_after_raw_wb = openpyxl.load_workbook(href_raw_address+"/"+country+" hreflang_all_raw.xlsx")
#     href_after_raw_ws = href_after_raw_wb['1 - All']
    

    

#     # columns 정렬
    
#     href_after_raw['Address'] = href_after_raw['Address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Address'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c073d007f325> in <module>
#      16                                    sheet_name = "hreflang 검수")
#      17     # columns 배열
# ---> 18     href_after_raw_check['Address'] = href_after_raw['Address']
#      19     href_after_raw_check['Sitemap hreflang 1'] = href_after_raw['Sitemap hreflang 1']
#      20     href_after_raw_check['Sitemap hreflang 1 URL'] = href_after_raw['Sitemap hreflang 1 URL']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Address'

# %%
href_after_raw = pd.read_excel(href_raw_address+"/"+country+" hreflang_all_raw.xlsx", sheet_name = "1 - All")

# %%
real_index = href_after_raw['Sitemap hreflang 1 URL'].dropna().index

# %%
not_null_raw = href_after_raw.iloc[real_index]

# %%
not_null_raw.head()
# Out:
#                                               Address  \
# 5   https://www.kia.com/aw/discover-kia/ask/what-a...
# 7   https://www.kia.com/aw/discover-kia/ask/what-i...
# 12  https://www.kia.com/aw/discover-kia/ask/are-el...
# 16       https://www.kia.com/aw/discover-kia/ask.html
# 17  https://www.kia.com/aw/discover-kia/ask/what-i...
#
#                                               Title 1  Occurrences  \
# 5   What are Kia Seltos engine options? | Kia Moto...           32
# 7   What is a VIN(Vehicle Identification Number)? ...           32
# 12  Are electric cars better for the environment? ...           32
# 16              ASK | Search Voice | Kia Motors Aruba           32
# 17          What is a summer tire? | Kia Motors Aruba           32
#
#    HTML hreflang 1                    HTML hreflang 1 URL HTML hreflang 2  \
# 5        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 7        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 12       x-default  https://www.kia.com/worldwide/main.do           en-aw
# 16       x-default  https://www.kia.com/worldwide/main.do           en-aw
# 17       x-default  https://www.kia.com/worldwide/main.do           en-aw
#
#                  HTML hreflang 2 URL HTML hreflang 3 HTML hreflang 3 URL  \
# 5   https://www.kia.com/aw/main.html             NaN                 NaN
# 7   https://www.kia.com/aw/main.html             NaN                 NaN
# 12  https://www.kia.com/aw/main.html             NaN                 NaN
# 16  https://www.kia.com/aw/main.html             NaN                 NaN
# 17  https://www.kia.com/aw/main.html             NaN                 NaN
#
#    HTML hreflang 4  ... Sitemap hreflang 34  Sitemap hreflang 34 URL  \
# 5              NaN  ...                 NaN                      NaN
# 7              NaN  ...                 NaN                      NaN
# 12             NaN  ...                 NaN                      NaN
# 16             NaN  ...                 NaN                      NaN
# 17             NaN  ...                 NaN                      NaN
#
#     Sitemap hreflang 35 Sitemap hreflang 35 URL Sitemap hreflang 36  \
# 5                   NaN                     NaN                 NaN
# 7                   NaN                     NaN                 NaN
# 12                  NaN                     NaN                 NaN
# 16                  NaN                     NaN                 NaN
# 17                  NaN                     NaN                 NaN
#
#    Sitemap hreflang 36 URL Sitemap hreflang 37 Sitemap hreflang 37 URL  \
# 5                      NaN                 NaN                     NaN
# 7                      NaN                 NaN                     NaN
# 12                     NaN                 NaN                     NaN
# 16                     NaN                 NaN                     NaN
# 17                     NaN                 NaN                     NaN
#
#    Sitemap hreflang 38 Sitemap hreflang 38 URL
# 5                  NaN                     NaN
# 7                  NaN                     NaN
# 12                 NaN                     NaN
# 16                 NaN                     NaN
# 17                 NaN                     NaN
#
# [5 rows x 89 columns]

# %%
not_null_raw['HTML hreflang 1 URL check'] = not_null_raw['HTML hreflang 1 URL'] == 'https://www.kia.com/worldwide/main.do'

# %%
not_null_raw.head()
# Out:
#                                               Address  \
# 5   https://www.kia.com/aw/discover-kia/ask/what-a...
# 7   https://www.kia.com/aw/discover-kia/ask/what-i...
# 12  https://www.kia.com/aw/discover-kia/ask/are-el...
# 16       https://www.kia.com/aw/discover-kia/ask.html
# 17  https://www.kia.com/aw/discover-kia/ask/what-i...
#
#                                               Title 1  Occurrences  \
# 5   What are Kia Seltos engine options? | Kia Moto...           32
# 7   What is a VIN(Vehicle Identification Number)? ...           32
# 12  Are electric cars better for the environment? ...           32
# 16              ASK | Search Voice | Kia Motors Aruba           32
# 17          What is a summer tire? | Kia Motors Aruba           32
#
#    HTML hreflang 1                    HTML hreflang 1 URL HTML hreflang 2  \
# 5        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 7        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 12       x-default  https://www.kia.com/worldwide/main.do           en-aw
# 16       x-default  https://www.kia.com/worldwide/main.do           en-aw
# 17       x-default  https://www.kia.com/worldwide/main.do           en-aw
#
#                  HTML hreflang 2 URL HTML hreflang 3 HTML hreflang 3 URL  \
# 5   https://www.kia.com/aw/main.html             NaN                 NaN
# 7   https://www.kia.com/aw/main.html             NaN                 NaN
# 12  https://www.kia.com/aw/main.html             NaN                 NaN
# 16  https://www.kia.com/aw/main.html             NaN                 NaN
# 17  https://www.kia.com/aw/main.html             NaN                 NaN
#
#    HTML hreflang 4  ... Sitemap hreflang 34 URL  Sitemap hreflang 35  \
# 5              NaN  ...                     NaN                  NaN
# 7              NaN  ...                     NaN                  NaN
# 12             NaN  ...                     NaN                  NaN
# 16             NaN  ...                     NaN                  NaN
# 17             NaN  ...                     NaN                  NaN
#
#     Sitemap hreflang 35 URL Sitemap hreflang 36 Sitemap hreflang 36 URL  \
# 5                       NaN                 NaN                     NaN
# 7                       NaN                 NaN                     NaN
# 12                      NaN                 NaN                     NaN
# 16                      NaN                 NaN                     NaN
# 17                      NaN                 NaN                     NaN
#
#    Sitemap hreflang 37 Sitemap hreflang 37 URL Sitemap hreflang 38  \
# 5                  NaN                     NaN                 NaN
# 7                  NaN                     NaN                 NaN
# 12                 NaN                     NaN                 NaN
# 16                 NaN                     NaN                 NaN
# 17                 NaN                     NaN                 NaN
#
#    Sitemap hreflang 38 URL HTML hreflang 1 URL check
# 5                      NaN                      True
# 7                      NaN                      True
# 12                     NaN                      True
# 16                     NaN                      True
# 17                     NaN                      True
#
# [5 rows x 90 columns]

# %%
as_href = not_null_raw['HTML hreflang 2'].str.split('-', n=1, expand=True).iloc[0,1]

# %%
as_href
# Out:
# 'aw'

# %%
not_null_raw['HTML hreflang 2 check'] = not_null_raw['HTML hreflang 2 URL'] ==\
'https://www.kia.com/'+as_href+'/main.html'

# %%
not_null_raw
# Out:
#                                                Address  \
# 5    https://www.kia.com/aw/discover-kia/ask/what-a...
# 7    https://www.kia.com/aw/discover-kia/ask/what-i...
# 12   https://www.kia.com/aw/discover-kia/ask/are-el...
# 16        https://www.kia.com/aw/discover-kia/ask.html
# 17   https://www.kia.com/aw/discover-kia/ask/what-i...
# 21   https://www.kia.com/aw/discover-kia/ask/how-is...
# 24   https://www.kia.com/aw/discover-kia/ask/what-c...
# 31   https://www.kia.com/aw/discover-kia/ask/what-d...
# 33   https://www.kia.com/aw/discover-kia/ask/how-to...
# 34   https://www.kia.com/aw/discover-kia/ask/what-i...
# 38   https://www.kia.com/aw/discover-kia/ask/how-lo...
# 45   https://www.kia.com/aw/discover-kia/ask/when-s...
# 52   https://www.kia.com/aw/discover-kia/ask/which-...
# 53   https://www.kia.com/aw/discover-kia/ask/how-mu...
# 56   https://www.kia.com/aw/discover-kia/ask/how-to...
# 58   https://www.kia.com/aw/discover-kia/ask/how-to...
# 60   https://www.kia.com/aw/discover-kia/ask/how-lo...
# 62   https://www.kia.com/aw/discover-kia/ask/how-is...
# 63   https://www.kia.com/aw/discover-kia/ask/how-to...
# 66   https://www.kia.com/aw/discover-kia/ask/what-d...
# 69   https://www.kia.com/aw/discover-kia/ask/how-to...
# 71   https://www.kia.com/aw/discover-kia/ask/what-p...
# 72   https://www.kia.com/aw/discover-kia/ask/what-d...
# 73   https://www.kia.com/aw/discover-kia/ask/how-lo...
# 75   https://www.kia.com/aw/discover-kia/ask/how-lo...
# 82   https://www.kia.com/aw/discover-kia/ask/which-...
# 85                    https://www.kia.com/aw/main.html
# 86   https://www.kia.com/aw/discover-kia/ask/how-ma...
# 91   https://www.kia.com/aw/discover-kia/ask/what-i...
# 95   https://www.kia.com/aw/discover-kia/ask/what-d...
# 105  https://www.kia.com/aw/discover-kia/ask/what-c...
# 109  https://www.kia.com/aw/discover-kia/ask/what-i...
#
#                                                Title 1  Occurrences  \
# 5    What are Kia Seltos engine options? | Kia Moto...           32
# 7    What is a VIN(Vehicle Identification Number)? ...           32
# 12   Are electric cars better for the environment? ...           32
# 16               ASK | Search Voice | Kia Motors Aruba           32
# 17           What is a summer tire? | Kia Motors Aruba           32
# 21   How is the Kia Seltos interior design? | Kia M...           32
# 24   What causes a car battery to drain? | Kia Moto...           32
# 31         What does car trim mean? | Kia Motors Aruba           32
# 33          How to clean car seats? | Kia Motors Aruba           32
# 34          What is Kia Seltos UVO? | Kia Motors Aruba           32
# 38   How long do summer tires last? | Kia Motors Aruba           32
# 45   When should I replace my car battery? | Kia Mo...           32
# 52   Which car battery terminal to connect first? |...           32
# 53   How much boot space does a Kia Seltos have? | ...           32
# 56   How to detail your car interior? | Kia Motors ...           32
# 58   How to change a car light bulb? | Kia Motors A...           32
# 60      How long do car tires last? | Kia Motors Aruba           32
# 62   How is the Kia Seltos sound system? | Kia Moto...           32
# 63     How to charge a car battery? | Kia Motors Aruba           32
# 66       What does Kia Seltos mean? | Kia Motors Aruba           32
# 69   How to connect Bluetooth to the car? | Kia Mot...           32
# 71   What pressure should my tires be? | Kia Motors...           32
# 72   What does SUV(Sports Utility Vehicle) stand fo...           32
# 73      How long is the Kia Seltos? | Kia Motors Aruba           32
# 75   How long does it take to charge an electric ca...           32
# 82   Which Kia SUV(Sports Utility Vehicle) is the b...           32
# 85   Kia Motors Aruba | Sedans, Hatchbacks, SUVs & ...           40
# 86   How many seats does a Kia Seltos have? | Kia M...           32
# 91   What is the New Kia SUV(Sports Utility Vehicle...           32
# 95   What does 4WD(Four-Wheel Drive) mean? | Kia Mo...           32
# 105  What color options does Kia Seltos have? | Kia...           32
# 109  What is Kia Seltos HUD(Head-up display) and ho...           32
#
#     HTML hreflang 1                    HTML hreflang 1 URL HTML hreflang 2  \
# 5         x-default  https://www.kia.com/worldwide/main.do           en-aw
# 7         x-default  https://www.kia.com/worldwide/main.do           en-aw
# 12        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 16        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 17        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 21        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 24        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 31        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 33        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 34        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 38        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 45        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 52        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 53        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 56        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 58        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 60        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 62        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 63        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 66        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 69        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 71        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 72        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 73        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 75        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 82        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 85        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 86        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 91        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 95        x-default  https://www.kia.com/worldwide/main.do           en-aw
# 105       x-default  https://www.kia.com/worldwide/main.do           en-aw
# 109       x-default  https://www.kia.com/worldwide/main.do           en-aw
#
#                   HTML hreflang 2 URL HTML hreflang 3 HTML hreflang 3 URL  \
# 5    https://www.kia.com/aw/main.html             NaN                 NaN
# 7    https://www.kia.com/aw/main.html             NaN                 NaN
# 12   https://www.kia.com/aw/main.html             NaN                 NaN
# 16   https://www.kia.com/aw/main.html             NaN                 NaN
# 17   https://www.kia.com/aw/main.html             NaN                 NaN
# 21   https://www.kia.com/aw/main.html             NaN                 NaN
# 24   https://www.kia.com/aw/main.html             NaN                 NaN
# 31   https://www.kia.com/aw/main.html             NaN                 NaN
# 33   https://www.kia.com/aw/main.html             NaN                 NaN
# 34   https://www.kia.com/aw/main.html             NaN                 NaN
# 38   https://www.kia.com/aw/main.html             NaN                 NaN
# 45   https://www.kia.com/aw/main.html             NaN                 NaN
# 52   https://www.kia.com/aw/main.html             NaN                 NaN
# 53   https://www.kia.com/aw/main.html             NaN                 NaN
# 56   https://www.kia.com/aw/main.html             NaN                 NaN
# 58   https://www.kia.com/aw/main.html             NaN                 NaN
# 60   https://www.kia.com/aw/main.html             NaN                 NaN
# 62   https://www.kia.com/aw/main.html             NaN                 NaN
# 63   https://www.kia.com/aw/main.html             NaN                 NaN
# 66   https://www.kia.com/aw/main.html             NaN                 NaN
# 69   https://www.kia.com/aw/main.html             NaN                 NaN
# 71   https://www.kia.com/aw/main.html             NaN                 NaN
# 72   https://www.kia.com/aw/main.html             NaN                 NaN
# 73   https://www.kia.com/aw/main.html             NaN                 NaN
# 75   https://www.kia.com/aw/main.html             NaN                 NaN
# 82   https://www.kia.com/aw/main.html             NaN                 NaN
# 85   https://www.kia.com/aw/main.html             NaN                 NaN
# 86   https://www.kia.com/aw/main.html             NaN                 NaN
# 91   https://www.kia.com/aw/main.html             NaN                 NaN
# 95   https://www.kia.com/aw/main.html             NaN                 NaN
# 105  https://www.kia.com/aw/main.html             NaN                 NaN
# 109  https://www.kia.com/aw/main.html             NaN                 NaN
#
#     HTML hreflang 4  ... Sitemap hreflang 35  \
# 5               NaN  ...                 NaN
# 7               NaN  ...                 NaN
# 12              NaN  ...                 NaN
# 16              NaN  ...                 NaN
# 17              NaN  ...                 NaN
# 21              NaN  ...                 NaN
# 24              NaN  ...                 NaN
# 31              NaN  ...                 NaN
# 33              NaN  ...                 NaN
# 34              NaN  ...                 NaN
# 38              NaN  ...                 NaN
# 45              NaN  ...                 NaN
# 52              NaN  ...                 NaN
# 53              NaN  ...                 NaN
# 56              NaN  ...                 NaN
# 58              NaN  ...                 NaN
# 60              NaN  ...                 NaN
# 62              NaN  ...                 NaN
# 63              NaN  ...                 NaN
# 66              NaN  ...                 NaN
# 69              NaN  ...                 NaN
# 71              NaN  ...                 NaN
# 72              NaN  ...                 NaN
# 73              NaN  ...                 NaN
# 75              NaN  ...                 NaN
# 82              NaN  ...                 NaN
# 85              NaN  ...               tr-tr
# 86              NaN  ...                 NaN
# 91              NaN  ...                 NaN
# 95              NaN  ...                 NaN
# 105             NaN  ...                 NaN
# 109             NaN  ...                 NaN
#
#                   Sitemap hreflang 35 URL  Sitemap hreflang 36  \
# 5                                     NaN                  NaN
# 7                                     NaN                  NaN
# 12                                    NaN                  NaN
# 16                                    NaN                  NaN
# 17                                    NaN                  NaN
# 21                                    NaN                  NaN
# 24                                    NaN                  NaN
# 31                                    NaN                  NaN
# 33                                    NaN                  NaN
# 34                                    NaN                  NaN
# 38                                    NaN                  NaN
# 45                                    NaN                  NaN
# 52                                    NaN                  NaN
# 53                                    NaN                  NaN
# 56                                    NaN                  NaN
# 58                                    NaN                  NaN
# 60                                    NaN                  NaN
# 62                                    NaN                  NaN
# 63                                    NaN                  NaN
# 66                                    NaN                  NaN
# 69                                    NaN                  NaN
# 71                                    NaN                  NaN
# 72                                    NaN                  NaN
# 73                                    NaN                  NaN
# 75                                    NaN                  NaN
# 82                                    NaN                  NaN
# 85   https://www.kia.com/tr/anasayfa.html                ru-ua
# 86                                    NaN                  NaN
# 91                                    NaN                  NaN
# 95                                    NaN                  NaN
# 105                                   NaN                  NaN
# 109                                   NaN                  NaN
#
#               Sitemap hreflang 36 URL Sitemap hreflang 37  \
# 5                                 NaN                 NaN
# 7                                 NaN                 NaN
# 12                                NaN                 NaN
# 16                                NaN                 NaN
# 17                                NaN                 NaN
# 21                                NaN                 NaN
# 24                                NaN                 NaN
# 31                                NaN                 NaN
# 33                                NaN                 NaN
# 34                                NaN                 NaN
# 38                                NaN                 NaN
# 45                                NaN                 NaN
# 52                                NaN                 NaN
# 53                                NaN                 NaN
# 56                                NaN                 NaN
# 58                                NaN                 NaN
# 60                                NaN                 NaN
# 62                                NaN                 NaN
# 63                                NaN                 NaN
# 66                                NaN                 NaN
# 69                                NaN                 NaN
# 71                                NaN                 NaN
# 72                                NaN                 NaN
# 73                                NaN                 NaN
# 75                                NaN                 NaN
# 82                                NaN                 NaN
# 85   https://www.kia.com/ua/main.html               mn-mn
# 86                                NaN                 NaN
# 91                                NaN                 NaN
# 95                                NaN                 NaN
# 105                               NaN                 NaN
# 109                               NaN                 NaN
#
#               Sitemap hreflang 37 URL Sitemap hreflang 38  \
# 5                                 NaN                 NaN
# 7                                 NaN                 NaN
# 12                                NaN                 NaN
# 16                                NaN                 NaN
# 17                                NaN                 NaN
# 21                                NaN                 NaN
# 24                                NaN                 NaN
# 31                                NaN                 NaN
# 33                                NaN                 NaN
# 34                                NaN                 NaN
# 38                                NaN                 NaN
# 45                                NaN                 NaN
# 52                                NaN                 NaN
# 53                                NaN                 NaN
# 56                                NaN                 NaN
# 58                                NaN                 NaN
# 60                                NaN                 NaN
# 62                                NaN                 NaN
# 63                                NaN                 NaN
# 66                                NaN                 NaN
# 69                                NaN                 NaN
# 71                                NaN                 NaN
# 72                                NaN                 NaN
# 73                                NaN                 NaN
# 75                                NaN                 NaN
# 82                                NaN                 NaN
# 85   https://www.kia.com/mn/main.html               th-th
# 86                                NaN                 NaN
# 91                                NaN                 NaN
# 95                                NaN                 NaN
# 105                               NaN                 NaN
# 109                               NaN                 NaN
#
#               Sitemap hreflang 38 URL HTML hreflang 1 URL check  \
# 5                                 NaN                      True
# 7                                 NaN                      True
# 12                                NaN                      True
# 16                                NaN                      True
# 17                                NaN                      True
# 21                                NaN                      True
# 24                                NaN                      True
# 31                                NaN                      True
# 33                                NaN                      True
# 34                                NaN                      True
# 38                                NaN                      True
# 45                                NaN                      True
# 52                                NaN                      True
# 53                                NaN                      True
# 56                                NaN                      True
# 58                                NaN                      True
# 60                                NaN                      True
# 62                                NaN                      True
# 63                                NaN                      True
# 66                                NaN                      True
# 69                                NaN                      True
# 71                                NaN                      True
# 72                                NaN                      True
# 73                                NaN                      True
# 75                                NaN                      True
# 82                                NaN                      True
# 85   https://www.kia.com/th/main.html                      True
# 86                                NaN                      True
# 91                                NaN                      True
# 95                                NaN                      True
# 105                               NaN                      True
# 109                               NaN                      True
#
#     HTML hreflang 2 check
# 5                    True
# 7                    True
# 12                   True
# 16                   True
# 17                   True
# 21                   True
# 24                   True
# 31                   True
# 33                   True
# 34                   True
# 38                   True
# 45                   True
# 52                   True
# 53                   True
# 56                   True
# 58                   True
# 60                   True
# 62                   True
# 63                   True
# 66                   True
# 69                   True
# 71                   True
# 72                   True
# 73                   True
# 75                   True
# 82                   True
# 85                   True
# 86                   True
# 91                   True
# 95                   True
# 105                  True
# 109                  True
#
# [32 rows x 91 columns]

# %%
print('https://www.kia.com/'+as_href+'/main.html')
# Out:
# https://www.kia.com/aw/main.html

# %%
"https://www.kia.com/"+country.lower()
# Out:
# 'https://www.kia.com/aw'

# %% [markdown]
# ## 10. CTA - 직접 싸이트에 들어가서 확인

# %% [markdown]
# ## 11. 내비게이션 버튼 - 직접 싸이트에 들어가서 확인

# %% [markdown]
# ## 12. 콘텐츠
