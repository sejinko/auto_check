# %%
import numpy as np
import pandas as pd
import warnings

# %% [markdown]
# ## 매뉴얼
#
# 1. 시작전 틀이 갖춰진 비어있는 엑셀 파일이 필요함.
# 2. 해당 URL을 검수 Raw 파일의 URL에 넣는다.
# 3.

# %% [markdown]
# ## 검수 국가 선택

# %%
countrys = ["AW"]

# %% [markdown]
# ## 경로설정

# %%
raw_address = "F:/OneDrive/12. 라이브 이후 검수/Raw"
href_raw_address = "F:/OneDrive/12. 라이브 이후 검수/Raw/Herflang RAW"
save_address = "F:/OneDrive/12. 라이브 이후 검수"

# %% [markdown]
# ## 전처리(Raw 데이터 정리)

# %%
for country in countrys:
    # 불러오기(Raw, check Raw, ckeck)
    after_raw = pd.read_excel(raw_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 ("+
                              country+")_200309 Raw.xlsx")

    after_check_raw = pd.read_excel(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 (AW)_200309.xlsx",
                           sheet_name ="검수 Raw")
    
    after_check = pd.read_excel(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 (AW)_200309.xlsx",
                           sheet_name ="검수")
    
    # 전처리
    
    
    # 우리가 검수할 URL을 검수 Sheet에 넣어놔야 함
#     after_check_raw['URL'] = after_raw['Address'][after_raw['Address'].values == after_check['URL'].values]
#     after_check_raw['URL 구조'] = 
    

    
    
    
    
 # 1. Raw 데이터를 검수 Raw sheet로 옮겨야 함
# 2. 검수 Raw sheet의 데이터를 를 비교하며 알맞은 항목을 검수 sheet에 "O",
# 이슈가 있는 항목은 검수 sheet에 "X"로 표기한다.

    
# hreflang은 따로 해야 함

# %%
after_raw.head()
# Out:
#                                              Address    Content  Status Code  \
# 0  https://www.kia.com/aw/discover-kia/ask/how-lo...  text/html          200
# 1  https://www.kia.com/aw/discover-kia/ask/what-i...  text/html          200
# 2  https://www.kia.com/aw/discover-kia/ask/when-s...  text/html          200
# 3  https://www.kia.com/aw/discover-kia/ask/what-i...  text/html          200
# 4  https://www.kia.com/aw/discover-kia/ask/how-is...  text/html          200
#
#   Status Indexability  Indexability Status  \
# 0     OK    Indexable                  NaN
# 1     OK    Indexable                  NaN
# 2     OK    Indexable                  NaN
# 3     OK    Indexable                  NaN
# 4     OK    Indexable                  NaN
#
#                                              Title 1  Title 1 Length  \
# 0     How long is the Kia Seltos? | Kia Motors Aruba              46
# 1  What is Kia Seltos HUD(Head-up display) and ho...              80
# ...

# %%
after_check_raw.head()
# Out:
#    국가명                                                URL  \
# 0  NaN  https://www.kia.com/aw/discover-kia/ask/how-is...
# 1  NaN  https://www.kia.com/aw/discover-kia/ask/how-is...
# 2  NaN  https://www.kia.com/aw/discover-kia/ask/how-lo...
# 3  NaN  https://www.kia.com/aw/discover-kia/ask/how-ma...
# 4  NaN  https://www.kia.com/aw/discover-kia/ask/how-mu...
#
#                                               URL 구조  \
# 0  https://www.kia.com/aw/discover-kia/ask/how-is...
# 1  https://www.kia.com/aw/discover-kia/ask/how-is...
# 2  https://www.kia.com/aw/discover-kia/ask/how-lo...
# 3  https://www.kia.com/aw/discover-kia/ask/how-ma...
# 4  https://www.kia.com/aw/discover-kia/ask/how-mu...
#
#                                          캐노니컬  \
# 0       How is the Kia Seltos interior design
# 1          How is the Kia Seltos sound system
# 2                  How long is the Kia Seltos
# 3       How many seats does a Kia Seltos have
# 4  How much boot space does a Kia Seltos have
#
# ...

# %%
 = after_check['URL'][i] == after_raw['Address']

after_raw['Address'].values == after_check['URL'].values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False])

# %%
after_check['URL'][0] == after_raw['Address']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Address, dtype: bool

# %%
url_index = after_raw[after_check['URL'][0] == after_raw['Address']].index[0]

# %%
url_index
# Out:
# 4

# %%
after_check_raw['URL 구조'][url_index]
# Out:
# 'https://www.kia.com/aw/discover-kia/ask/how-much-boot-space-does-a-kia-seltos-have.html'

# %%
after_raw.shape[0]
# Out:
# 20

# %%
for i in after_check.shape[0]:
    if i < after_raw.shape[0]
        url_index = after_raw[after_check['URL'][i] == after_raw['Address']].index[0]
    else :
        break
        
    # 1.URL
    after_check_raw['URL'][i] = after_raw['Address'][url_index]
    
    # 2.URL 구조
    after_check_raw['URL 구조'][i] = after_raw['Address'][url_index]

    # 3.캐노니컬
    after_check_raw['캐노니컬'][i] = after_raw['Canonical Link Element 1'][url_index]

    # 4.타이틀
    after_check_raw['타이틀'][i] = after_raw['Title 1'][url_index]

    # 5.디스크립션
    after_check_raw['디스크립션'][i] = after_raw['Meta Description 1'][url_index]

    # 6.OG
    after_check_raw['OG(Site name)'][i] = after_raw[''][url_index]
    after_check_raw['OG(Type)'][i] = after_raw[''][url_index]
    after_check_raw['OG(Title)'][ix] = after_raw[''][url_index]
    after_check_raw['OG(Description)'][i] = after_raw[''][url_index]
    after_check_raw['OG(URL)'][i] = after_raw[''][url_index]

    # 7.Twitter
    after_check_raw['Twitter((Site)'][i] = after_raw[''][url_index]
    after_check_raw['Twitter(Title)'][i] = after_raw[''][url_index]
    after_check_raw['Twitter(Description)'][i] = after_raw[''][url_index]
    after_check_raw['Twitter(URL)'][i] = after_raw[''][url_index]
    after_check_raw['Twitter(Image)'][i] = after_raw[''][url_index]
    after_check_raw['Twitter(Twitter Card)'][i] = after_raw[''][url_index]

    # 8.Schema
    after_check_raw['Schema(Name)'][i] = after_raw[''][url_index]
    after_check_raw['Schema(Description)'][i] = after_raw[''][url_index]
    after_check_raw['Schema(URL)'][i] = after_raw[''][url_index]
    after_check_raw['Schema(Breadcrumb)'][i] = after_raw[''][url_index]
    after_check_raw['Schema(type)'][i] = after_raw[''][url_index]

    # 9.H tag
    after_check_raw['H tag(H1)'][i] = after_raw[''][url_index]
    after_check_raw['H tag(H2-1)'][i] = after_raw[''][url_index]
    after_check_raw['H tag(H2-2)'][i] = after_raw[''][url_index]

    # 11.Hreflang
    after_check_raw['Hreflang'][i] = after_raw[''][url_index]

    # 12.CTA
    after_check_raw['CTA'][i] = after_raw[''][url_index]

    # 13.내비게이션 버튼
    after_check_raw['내비게이션 버튼'][i] = after_raw[''][url_index]

    # 14.콘텐츠
    after_check_raw['콘텐츠'][i] = after_raw[''][url_index]
# Out:
#   File "<ipython-input-43-26d67cf3fff6>", line 1
#     after_check_raw['URL 구조'] =
#                                 ^
# SyntaxError: invalid syntax

# %%
after_live.head()
# Out:
#   국가명                                                URL URL 구조 캐노니컬 타이틀  \
# 0  AW  https://www.kia.com/aw/discover-kia/ask/how-is...      O    O   O
# 1  AW  https://www.kia.com/aw/discover-kia/ask/how-is...      O    O   O
# 2  AW  https://www.kia.com/aw/discover-kia/ask/how-lo...      O    O   O
# 3  AW  https://www.kia.com/aw/discover-kia/ask/how-ma...      O    O   O
# 4  AW  https://www.kia.com/aw/discover-kia/ask/how-mu...      O    O   O
#
#   디스크립션 OG(Site name) OG(Type) OG(Title) OG(Description)  ... Schema(URL)  \
# 0     O             O        O         O               O  ...           O
# 1     O             O        O         O               O  ...           O
# 2     O             O        O         O               O  ...           O
# 3     O             O        O         O               O  ...           O
# 4     O             O        O         O               O  ...           O
#
#   Schema(Breadcrumb) Schema(type) H tag(H1) H tag(H2-1) H tag(H2-2) Hreflang  \
# ...

# %%
after_live_raw = pd.read_excel(save_address+"/"+"2차, 3차 음성 검색 콘텐츠 라이브 이후 검수 (AW)_200309.xlsx",
                           sheet_name ="검수 Raw")

# %%
after_live_raw.head()
# Out:
#    국가명                                                URL  \
# 0  NaN  https://www.kia.com/aw/discover-kia/ask/how-is...
# 1  NaN  https://www.kia.com/aw/discover-kia/ask/how-is...
# 2  NaN  https://www.kia.com/aw/discover-kia/ask/how-lo...
# 3  NaN  https://www.kia.com/aw/discover-kia/ask/how-ma...
# 4  NaN  https://www.kia.com/aw/discover-kia/ask/how-mu...
#
#                                               URL 구조  \
# 0  https://www.kia.com/aw/discover-kia/ask/how-is...
# 1  https://www.kia.com/aw/discover-kia/ask/how-is...
# 2  https://www.kia.com/aw/discover-kia/ask/how-lo...
# 3  https://www.kia.com/aw/discover-kia/ask/how-ma...
# 4  https://www.kia.com/aw/discover-kia/ask/how-mu...
#
#                                          캐노니컬  \
# 0       How is the Kia Seltos interior design
# 1          How is the Kia Seltos sound system
# 2                  How long is the Kia Seltos
# 3       How many seats does a Kia Seltos have
# 4  How much boot space does a Kia Seltos have
#
# ...

# %% [markdown]
# ## 1. URL 구조

# %%
for country in countrys:

# %% [markdown]
# ## 2. 캐노니컬

# %% [markdown]
# ## 3. 타이틀

# %% [markdown]
# ## 4. 디스크립션

# %% [markdown]
# ## 5. OG(site name, Type, Title, Description, URL)

# %% [markdown]
# ## 6. Twitter(Site, Title, Description, URL, Image, Twitter Card)

# %% [markdown]
# ## 7. Schema(Name, Description, URL, Breadcrumb, type)

# %% [markdown]
# ## 8. H tag(H1, H2_1, H2_2)

# %% [markdown]
# ## 9. Hreflang

# %% [markdown]
# ## 10. CTA

# %% [markdown]
# ## 11. 내비게이션 버튼

# %% [markdown]
# ## 12. 콘텐츠
